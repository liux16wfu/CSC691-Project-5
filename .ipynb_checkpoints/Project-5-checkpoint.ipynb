# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.metrics import plot_confusion_matrix
import seaborn as sn
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Dealing with Missing Values
# The test data does not contain any label for survival, due to the nature of competetion. Therefore, we will primarily focus on the training data provided.

# %%
train_df = pd.read_csv('./train.csv',index_col='PassengerId')

# %%
train_df.describe(include='all')
# Out:
#           Survived      Pclass                 Name   Sex         Age  \
# count   891.000000  891.000000                  891   891  714.000000
# unique         NaN         NaN                  891     2         NaN
# top            NaN         NaN  Olsson, Miss. Elina  male         NaN
# freq           NaN         NaN                    1   577         NaN
# mean      0.383838    2.308642                  NaN   NaN   29.699118
# std       0.486592    0.836071                  NaN   NaN   14.526497
# min       0.000000    1.000000                  NaN   NaN    0.420000
# 25%       0.000000    2.000000                  NaN   NaN   20.125000
# 50%       0.000000    3.000000                  NaN   NaN   28.000000
# 75%       1.000000    3.000000                  NaN   NaN   38.000000
# max       1.000000    3.000000                  NaN   NaN   80.000000
#
#              SibSp       Parch    Ticket        Fare Cabin Embarked
# ...

# %% [markdown]
# As we see from the decription, missing values are everywhere. However, some of the categorical features involves the number 0 which is accidentally counted as missing values.
#
# Let's find all the missing values.

# %%
for i in train_df.columns:
    print('Number of missing values in %s : %d'% (i,(train_df[i].isnull()==True).sum()))
# Out:
# Number of missing values in Survived : 0
# Number of missing values in Pclass : 0
# Number of missing values in Name : 0
# Number of missing values in Sex : 0
# Number of missing values in Age : 177
# Number of missing values in SibSp : 0
# Number of missing values in Parch : 0
# Number of missing values in Ticket : 0
# Number of missing values in Fare : 0
# Number of missing values in Cabin : 687
# Number of missing values in Embarked : 2

# %% [markdown]
# Age and Cabin have the most missing values. Embarked only contains 2. However, we believe Embarked feature is not useful in terms of predicting the survivors of Titanic and the Cabin information is corelated to the Fare and Passenger Class so we can discard the two.
#
# Now we need to impute the age entries. Since the age distribution is unlikely to be normal, it makes more sense to impute the ages with the median instead of mean.From description, the median of age is 28.

# %%
age = train_df['Age'].values
age = np.array([28 if np.isnan(i) else i for i in age])
train_df['Age'] = age

# %% [markdown]
# Let's see the imputed data's description.

# %%
train_df['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# Turn the Sex feature into integers.

# %%
sex = train_df['Sex'].values
sex = np.array([0 if i=='male' else 1 for i in sex])
train_df['Sex'] = sex

# %% [markdown]
# Discard unwanted features and prepare data from classification.

# %%
train_df = train_df.drop(['Name', 'Ticket', 'Cabin', 'Embarked'], axis=1)

# %%
X = train_df[train_df.columns[1:]].values
y = train_df['Survived'].values


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
X_train = X_train.reshape((-1, 6))
X_test = X_test.reshape((-1, 6))

y_train = to_categorical(y_train)

# %% [markdown]
# The process of dealing with missing data follows the ACM Code of Ethics and Professional Conduct(https://www.acm.org/code-of-ethics). If there is any ethical concern with the use of data, please contact me by liux16@wfu.edu.

# %% [markdown]
# ### Deep Neural Netwrok Model
# Define a simple two hidden layer model.

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(32, activation=tf.nn.relu, input_shape=(6,)))
model.add(tf.keras.layers.Dense(32, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(2, activation=tf.nn.softmax))

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(x=X_train, y=y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 20/20 - 0s - loss: 2.2528 - accuracy: 0.5522
# Epoch 2/50
# 20/20 - 0s - loss: 1.0932 - accuracy: 0.6918
# Epoch 3/50
# 20/20 - 0s - loss: 0.6639 - accuracy: 0.7030
# Epoch 4/50
# 20/20 - 0s - loss: 0.6096 - accuracy: 0.6758
# Epoch 5/50
# 20/20 - 0s - loss: 0.6267 - accuracy: 0.6966
# Epoch 6/50
# 20/20 - 0s - loss: 0.6306 - accuracy: 0.6918
# Epoch 7/50
# 20/20 - 0s - loss: 0.6831 - accuracy: 0.6677
# Epoch 8/50
# 20/20 - 0s - loss: 0.6535 - accuracy: 0.6918
# Epoch 9/50
# 20/20 - 0s - loss: 0.6494 - accuracy: 0.7159
# Epoch 10/50
# 20/20 - 0s - loss: 0.5606 - accuracy: 0.7239
# Epoch 11/50
# 20/20 - 0s - loss: 0.6540 - accuracy: 0.6838
# Epoch 12/50
# 20/20 - 0s - loss: 0.5953 - accuracy: 0.7239
# Epoch 13/50
# 20/20 - 0s - loss: 0.6373 - accuracy: 0.7159
# Epoch 14/50
# 20/20 - 0s - loss: 0.5310 - accuracy: 0.7368
# Epoch 15/50
# 20/20 - 0s - loss: 0.5518 - accuracy: 0.7368
# Epoch 16/50
# 20/20 - 0s - loss: 0.5791 - accuracy: 0.7368
# Epoch 17/50
# ...

# %%
y_pred = model.predict([X_test])
y_pred = np.argmax(y_pred, axis=1)
accuracy_score(y_test, y_pred)
# Out:
# 0.7089552238805971

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[143,  10],
#        [ 68,  47]])

# %% [markdown]
# #### Tune the hyper parameters.

# %%
accur = []
for i in range(4,8):
    for j in range(4,8):
        model = tf.keras.models.Sequential()
        model.add(tf.keras.layers.Dense(2**i, activation=tf.nn.relu, input_shape=(6,)))
        model.add(tf.keras.layers.Dense(2**j, activation=tf.nn.relu))
        model.add(tf.keras.layers.Dense(2, activation=tf.nn.softmax))

        model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        model.fit(x=X_train, y=y_train, epochs=50, verbose=2) 
        y_pred = model.predict([X_test])
        y_pred = np.argmax(y_pred, axis=1)
        accur.append(accuracy_score(y_test, y_pred))
# Out:
# Epoch 1/50
# 20/20 - 0s - loss: 9.1957 - accuracy: 0.3644
# Epoch 2/50
# 20/20 - 0s - loss: 3.8609 - accuracy: 0.3740
# Epoch 3/50
# 20/20 - 0s - loss: 1.4459 - accuracy: 0.5955
# Epoch 4/50
# 20/20 - 0s - loss: 1.0765 - accuracy: 0.6469
# Epoch 5/50
# 20/20 - 0s - loss: 0.9675 - accuracy: 0.6565
# Epoch 6/50
# 20/20 - 0s - loss: 0.8970 - accuracy: 0.6629
# Epoch 7/50
# 20/20 - 0s - loss: 0.8164 - accuracy: 0.6597
# Epoch 8/50
# 20/20 - 0s - loss: 0.7291 - accuracy: 0.6581
# Epoch 9/50
# 20/20 - 0s - loss: 0.6688 - accuracy: 0.6597
# Epoch 10/50
# 20/20 - 0s - loss: 0.6271 - accuracy: 0.6886
# Epoch 11/50
# 20/20 - 0s - loss: 0.6107 - accuracy: 0.6886
# Epoch 12/50
# 20/20 - 0s - loss: 0.6185 - accuracy: 0.6806
# Epoch 13/50
# 20/20 - 0s - loss: 0.5951 - accuracy: 0.6918
# Epoch 14/50
# 20/20 - 0s - loss: 0.5958 - accuracy: 0.6918
# Epoch 15/50
# 20/20 - 0s - loss: 0.5870 - accuracy: 0.6918
# Epoch 16/50
# 20/20 - 0s - loss: 0.5760 - accuracy: 0.7030
# Epoch 17/50
# ...

# %%
plt.plot(np.arange(16)+1, accur, marker='o')
plt.xlabel('Configurations')
plt.ylabel('Accuracy with 50 epochs')
# Out:
# Text(0, 0.5, 'Accuracy with 50 epochs')

# %% [markdown]
# The highest accuracy is achieved with hidden layers (256, 128). Let's retrain the model.

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(256, activation=tf.nn.relu, input_shape=(6,)))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(2, activation=tf.nn.softmax))

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

model.fit(x=X_train, y=y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 20/20 - 0s - loss: 0.7686 - accuracy: 0.6597
# Epoch 2/50
# 20/20 - 0s - loss: 0.6554 - accuracy: 0.7111
# Epoch 3/50
# 20/20 - 0s - loss: 0.7527 - accuracy: 0.6838
# Epoch 4/50
# 20/20 - 0s - loss: 0.5353 - accuracy: 0.7432
# Epoch 5/50
# 20/20 - 0s - loss: 0.5529 - accuracy: 0.7576
# Epoch 6/50
# 20/20 - 0s - loss: 0.5141 - accuracy: 0.7721
# Epoch 7/50
# 20/20 - 0s - loss: 0.5064 - accuracy: 0.7592
# Epoch 8/50
# 20/20 - 0s - loss: 0.5322 - accuracy: 0.7576
# Epoch 9/50
# 20/20 - 0s - loss: 0.5612 - accuracy: 0.7673
# Epoch 10/50
# 20/20 - 0s - loss: 0.4933 - accuracy: 0.7737
# Epoch 11/50
# 20/20 - 0s - loss: 0.6279 - accuracy: 0.7480
# Epoch 12/50
# 20/20 - 0s - loss: 0.6091 - accuracy: 0.7464
# Epoch 13/50
# 20/20 - 0s - loss: 0.5232 - accuracy: 0.7801
# Epoch 14/50
# 20/20 - 0s - loss: 0.4497 - accuracy: 0.7865
# Epoch 15/50
# 20/20 - 0s - loss: 0.4787 - accuracy: 0.7865
# Epoch 16/50
# 20/20 - 0s - loss: 0.5174 - accuracy: 0.7769
# Epoch 17/50
# ...

# %%
y_pred = model.predict([X_test])
y_pred = np.argmax(y_pred, axis=1)
print('The accuracy score: ', accuracy_score(y_test, y_pred))
# Out:
# The accuracy score:  0.7350746268656716

# %%
fig = sn.heatmap(confusion_matrix(y_test, y_pred),annot=True, fmt='g')

# %% [markdown]
# ### Decision Tree Model
# Define a simple DecisionTree Classifier.

# %%
clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
print('The accuracy score: ', accuracy_score(y_test, y_pred))
# Out:
# The accuracy score:  0.7388059701492538

# %% [markdown]
# #### Tune the hyper parameters.

# %%
accur = []

for c in ['gini', 'entropy']:
    for alpha in [1, 0.1, 0.01, 0.001, 0.0001, 0.00001]:
        clf = DecisionTreeClassifier(criterion=c, ccp_alpha=alpha).fit(X_train, y_train)
            
        y_pred = clf.predict(X_test)
        y_pred = np.argmax(y_pred, axis=1)
            
        accur.append(accuracy_score(y_test, y_pred))
        print('criterion = ', c, ', alpha = ', alpha,'; Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# criterion =  gini , alpha =  1 ; Accuracy: 0.5708955223880597
# criterion =  gini , alpha =  0.1 ; Accuracy: 0.753731343283582
# criterion =  gini , alpha =  0.01 ; Accuracy: 0.7873134328358209
# criterion =  gini , alpha =  0.001 ; Accuracy: 0.75
# criterion =  gini , alpha =  0.0001 ; Accuracy: 0.7425373134328358
# criterion =  gini , alpha =  1e-05 ; Accuracy: 0.7313432835820896
# criterion =  entropy , alpha =  1 ; Accuracy: 0.5708955223880597
# criterion =  entropy , alpha =  0.1 ; Accuracy: 0.753731343283582
# criterion =  entropy , alpha =  0.01 ; Accuracy: 0.7761194029850746
# criterion =  entropy , alpha =  0.001 ; Accuracy: 0.7425373134328358
# criterion =  entropy , alpha =  0.0001 ; Accuracy: 0.75
# criterion =  entropy , alpha =  1e-05 ; Accuracy: 0.75

# %%
plt.plot(np.arange(12)+1, accur, marker='o')
plt.xlabel('Configurations')
plt.ylabel('Accuracy with 50 epochs')
# Out:
# Text(0, 0.5, 'Accuracy with 50 epochs')

# %% [markdown]
# The highest accuracy is achieved with Gini impurity and alpha = 0.01.

# %%
clf = DecisionTreeClassifier(criterion='gini', ccp_alpha=0.01).fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
print('The accuracy score: ', accuracy_score(y_test, y_pred))
# Out:
# The accuracy score:  0.7873134328358209

# %%
fig = sn.heatmap(confusion_matrix(y_test, y_pred),annot=True, fmt='g')

# %% [markdown]
# Our decision tree looks very balanced.

# %%
fig = tree.plot_tree(clf)

# %% [markdown]
# Both models have similar performances in terms of accuracy. The Decision Tree model has a higher accuracy of $78.73\%$ and has less false positives in the confusion matrix while the DNN model has less false negatives.
